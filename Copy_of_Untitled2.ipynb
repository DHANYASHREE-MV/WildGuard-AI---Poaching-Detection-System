# %%
# !mkdir yolov_11_custom

# %%
# %cd yolov_11_custom
# Out:
# /content/yolov_11_custom

# %%
# !python --version
# Out:
# Python 3.11.12

# %%
# !pip install ultralytics
import torch

# Check if GPU is available
print("CUDA Available:", torch.cuda.is_available())

# Optional: Check which GPU you're using
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 98.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 39.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !ls
# Out:
# dataset_custom.yaml  train.py  yolo11m.pt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b09a33b4-5426-4476-bdd7-72786c87e658" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b09a33b4-5426-4476-bdd7-72786c87e658">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile("yolov_11_custom.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/")

# %%
from ultralytics import YOLO
model = YOLO("yolo11m.pt")
model.train(data="dataset_custom.yaml", imgsz=640, batch=8, epochs=100, device=0)
# Out:
# Ultralytics 8.3.123 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp /content/yolov_11_custom/runs/detect/train3/weights/best.pt /content/yolov_11_custom/

# %%
! cp /content/yolov_11_custom/runs/detect/train3/weights/best.pt /content/yolov_11_custom/

# %%
# !python predict.py
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/yolov_11_custom/1.jpg: 480x640 3 Visitors, 57.4ms
# Speed: 3.2ms preprocess, 57.4ms inference, 161.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2

# %%
from IPython.display import Image, display
import glob

# Get the latest prediction image(s)
prediction_images = glob.glob('runs/detect/predict/1.jpg')  # or .png depending on your output

# Display each image
for img_path in prediction_images:
    display(Image(filename=img_path))
